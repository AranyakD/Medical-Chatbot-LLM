# %%
import pandas as pd

df = pd.read_csv("../data/medquad.csv")
df.head()
# Out:
#                                  question  \
# 0                What is (are) Glaucoma ?
# 1                  What causes Glaucoma ?
# 2     What are the symptoms of Glaucoma ?
# 3  What are the treatments for Glaucoma ?
# 4                What is (are) Glaucoma ?
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
#
#   focus_area
# 0   Glaucoma
# 1   Glaucoma
# 2   Glaucoma
# 3   Glaucoma
# 4   Glaucoma

# %%
df = df[['question', 'answer']].copy()
df = df.dropna()

# %%
df["input_text"] = "Answer medically: " + df["question"]
df["target_text"] = df["answer"]

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['question', 'answer', 'input_text', 'target_text'], dtype='object')
#                                  question  \
# 0                What is (are) Glaucoma ?
# 1                  What causes Glaucoma ?
# 2     What are the symptoms of Glaucoma ?
# 3  What are the treatments for Glaucoma ?
# 4                What is (are) Glaucoma ?
#
#                                               answer  \
# 0  Glaucoma is a group of diseases that can damag...
# 1  Nearly 2.7 million people have glaucoma, a lea...
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...
# 3  Although open-angle glaucoma cannot be cured, ...
# 4  Glaucoma is a group of diseases that can damag...
#
#                                           input_text  \
# 0         Answer medically: What is (are) Glaucoma ?
# 1           Answer medically: What causes Glaucoma ?
# 2  Answer medically: What are the symptoms of Gla...
# 3  Answer medically: What are the treatments for ...
# 4         Answer medically: What is (are) Glaucoma ?
#
#                                          target_text
# 0  Glaucoma is a group of diseases that can damag...
# 1  Nearly 2.7 million people have glaucoma, a lea...
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...
# 3  Although open-angle glaucoma cannot be cured, ...
# 4  Glaucoma is a group of diseases that can damag...

# %%
def clean_answer(text):
    if isinstance(text, str):
        return ". ".join(text.split(".")[:3])
    return text 

df['answer'] = df['answer'].apply(clean_answer)

# %%
df["target_text"] = df["answer"]

# %%
df.head()
# Out:
#                                  question  \
# 0                What is (are) Glaucoma ?
# 1                  What causes Glaucoma ?
# 2     What are the symptoms of Glaucoma ?
# 3  What are the treatments for Glaucoma ?
# 4                What is (are) Glaucoma ?
#
#                                               answer  \
# 0  Glaucoma is a group of diseases that can damag...
# 1  Nearly 2. 7 million people have glaucoma, a le...
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...
# 3  Although open-angle glaucoma cannot be cured, ...
# 4  Glaucoma is a group of diseases that can damag...
#
#                                           input_text  \
# 0         Answer medically: What is (are) Glaucoma ?
# 1           Answer medically: What causes Glaucoma ?
# 2  Answer medically: What are the symptoms of Gla...
# 3  Answer medically: What are the treatments for ...
# 4         Answer medically: What is (are) Glaucoma ?
#
#                                          target_text
# 0  Glaucoma is a group of diseases that can damag...
# 1  Nearly 2. 7 million people have glaucoma, a le...
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...
# 3  Although open-angle glaucoma cannot be cured, ...
# 4  Glaucoma is a group of diseases that can damag...

# %%
df.isnull().sum()
# Out:
# question       0
# answer         0
# input_text     0
# target_text    0
# dtype: int64

# %%
len(df)
# Out:
# 16407

# %%
df.to_csv("../data/medquad_cleaned.csv", index=False)
